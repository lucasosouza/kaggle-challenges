# %%
# import useful stuff
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
import re
import numpy as np

from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedShuffleSplit

from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import accuracy_score

# avoid undefined metric warning when calculating precision with 0 labels defined as 1
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Analysis (complement)

# %%
# conyuemp and ult_fec_cli_1t represent edge cases, 
# respectively is spouse of employee or last date as primary customer (if was a primary customer and it is not)
# renta is another issue with almost 20% without renta information
# df_train.isnull().sum()/df_train.shape[0]

# %%
# showing cod_prov and nomprov have the same data, so one of them can be ignored
# pd.pivot_table(df_train[['cod_prov', 'nomprov']], index= ['cod_prov', 'nomprov'],
#              aggfunc=len)[:10]à

# %%
# fecha_dato onluy have few entries. treat it categorical
# df_train['fecha_dato'].value_counts()

# %%
# check if antiguedad and fecha_alta - fecha_dato hold the same info
#X['fecha_alta_month'] = X['fecha_alta']/30 + (35-30.0333333)
#np.corrcoef(X.ix[:100, 'fecha_alta_month'], X.ix[:100, 'antiguedad'])

# there are little variations on the data, but they are basically the same. I actually only need one

# %% [markdown]
# ### Data transformations (from data analysis)

# %%
df_train = pd.read_csv('train_ver2.csv')

# %%
1.553689e+06
# Out:
# 1553689.0

# %%
df_train['ncodpers'].describe()
# Out:
# count    1.364731e+07
# mean     8.349042e+05
# std      4.315650e+05
# min      1.588900e+04
# 25%      4.528130e+05
# 50%      9.318930e+05
# 75%      1.199286e+06
# max      1.553689e+06
# Name: ncodpers, dtype: float64

# %%
a = df_train['ncodpers'].value_counts()[:-10]

# %%
a[a==11][:10]
# Out:
# 1121701    11
# 1360215    11
# 1009355    11
# 1400613    11
# 244505     11
# 1361330    11
# 991576     11
# 1418682    11
# 746093     11
# 1336742    11
# Name: ncodpers, dtype: int64

# %%
df_test = pd.read_csv('test_ver2.csv')

# %%
df_test['ncodpers'].describe()
# Out:
# count    9.296150e+05
# mean     8.794566e+05
# std      4.481569e+05
# min      1.588900e+04
# 25%      4.833615e+05
# 50%      9.664250e+05
# 75%      1.264316e+06
# max      1.553689e+06
# Name: ncodpers, dtype: float64

# %%
# separate the labels
labels = []
for col in df_train.columns:
    if col[:4] == 'ind_' and col[-4:] == 'ult1':
        labels.append(col)

# %%
len(labels)
# Out:
# 24

# %%
df_train.ix[df_train['ncodpers'] == 244505, ['fecha_dato', 'fecha_alta', 'segmento'] + labels[:12]]
# Out:
#           fecha_dato  fecha_alta segmento  ind_ahor_fin_ult1  \
# 4192196   2015-07-28  2001-05-07      NaN                  0
# 5401965   2015-08-28  2001-05-07      NaN                  0
# 5787252   2015-09-28  2001-05-07      NaN                  0
# 6796618   2015-10-28  2001-05-07      NaN                  0
# 7562309   2015-11-28  2001-05-07      NaN                  0
# 8529556   2015-12-28  2001-05-07      NaN                  0
# 9149943   2016-01-28  2001-05-07      NaN                  0
# 10517798  2016-02-28  2001-05-07      NaN                  0
# 11130797  2016-03-28  2001-05-07      NaN                  0
# 12106201  2016-04-28  2001-05-07      NaN                  0
# 12986532  2016-05-28  2001-05-07      NaN                  0
#
#           ind_aval_fin_ult1  ind_cco_fin_ult1  ind_cder_fin_ult1  \
# 4192196                   0                 0                  0
# 5401965                   0                 0                  0
# 5787252                   0                 0                  0
# 6796618                   0                 0                  0
# 7562309                   0                 0                  0
# 8529556                   0                 0                  0
# 9149943                   0                 0                  0
# 10517798                  0                 0                  0
# 11130797                  0                 0                  0
# 12106201                  0                 0                  0
# 12986532                  0                 0                  0
#
#           ind_cno_fin_ult1  ind_ctju_fin_ult1  ind_ctma_fin_ult1  \
# 4192196                  0                  0                  0
# 5401965                  0                  0                  0
# 5787252                  0                  0                  0
# 6796618                  0                  0                  0
# 7562309                  0                  0                  0
# 8529556                  0                  0                  0
# 9149943                  0                  0                  0
# 10517798                 0                  0                  0
# 11130797                 0                  0                  0
# 12106201                 0                  0                  0
# 12986532                 0                  0                  0
#
#           ind_ctop_fin_ult1  ind_ctpp_fin_ult1  ind_deco_fin_ult1  \
# 4192196                   0                  0                  0
# 5401965                   0                  0                  0
# 5787252                   0                  0                  0
# 6796618                   0                  0                  0
# 7562309                   0                  0                  0
# 8529556                   0                  0                  0
# 9149943                   0                  0                  0
# 10517798                  0                  0                  0
# 11130797                  0                  0                  0
# 12106201                  0                  0                  0
# 12986532                  0                  0                  0
#
#           ind_deme_fin_ult1  ind_dela_fin_ult1
# 4192196                   0                  0
# 5401965                   0                  0
# 5787252                   0                  0
# 6796618                   0                  0
# 7562309                   0                  0
# 8529556                   0                  0
# 9149943                   0                  0
# 10517798                  0                  0
# 11130797                  0                  0
# 12106201                  0                  0
# 12986532                  0                  0

# %%
df_train.ix[df_train['ncodpers'] == 1121701, ['fecha_dato', 'fecha_alta', 'ind_actividad_cliente'] + labels[12:]]
# Out:
#           fecha_dato  fecha_alta  ind_actividad_cliente  ind_ecue_fin_ult1  \
# 4244503   2015-07-28  2013-02-14                    0.0                  0
# 5129450   2015-08-28  2013-02-14                    0.0                  0
# 6135767   2015-09-28  2013-02-14                    0.0                  0
# 6327519   2015-10-28  2013-02-14                    0.0                  0
# 8031270   2015-11-28  2013-02-14                    0.0                  0
# 8438263   2015-12-28  2013-02-14                    0.0                  0
# 9720679   2016-01-28  2013-02-14                    0.0                  0
# 10665732  2016-02-28  2013-02-14                    0.0                  0
# 11613214  2016-03-28  2013-02-14                    0.0                  0
# 12271602  2016-04-28  2013-02-14                    0.0                  0
# 13606851  2016-05-28  2013-02-14                    0.0                  0
#
#           ind_fond_fin_ult1  ind_hip_fin_ult1  ind_plan_fin_ult1  \
# 4244503                   0                 0                  0
# 5129450                   0                 0                  0
# 6135767                   0                 0                  0
# 6327519                   0                 0                  0
# 8031270                   0                 0                  0
# 8438263                   0                 0                  0
# 9720679                   0                 0                  0
# 10665732                  0                 0                  0
# 11613214                  0                 0                  0
# 12271602                  0                 0                  0
# 13606851                  0                 0                  0
#
#           ind_pres_fin_ult1  ind_reca_fin_ult1  ind_tjcr_fin_ult1  \
# 4244503                   0                  0                  0
# 5129450                   0                  0                  0
# 6135767                   0                  0                  0
# 6327519                   0                  0                  0
# 8031270                   0                  0                  0
# 8438263                   0                  0                  0
# 9720679                   0                  0                  0
# 10665732                  0                  0                  0
# 11613214                  0                  0                  0
# 12271602                  0                  0                  0
# 13606851                  0                  0                  0
#
#           ind_valo_fin_ult1  ind_viv_fin_ult1  ind_nomina_ult1  \
# 4244503                   0                 0              0.0
# 5129450                   0                 0              0.0
# 6135767                   0                 0              0.0
# 6327519                   0                 0              0.0
# 8031270                   0                 0              0.0
# 8438263                   0                 0              0.0
# 9720679                   0                 0              0.0
# 10665732                  0                 0              0.0
# 11613214                  0                 0              0.0
# 12271602                  0                 0              0.0
# 13606851                  0                 0              0.0
#
#           ind_nom_pens_ult1  ind_recibo_ult1
# 4244503                 0.0                0
# 5129450                 0.0                0
# 6135767                 0.0                0
# 6327519                 0.0                0
# 8031270                 0.0                0
# 8438263                 0.0                0
# 9720679                 0.0                0
# 10665732                0.0                0
# 11613214                0.0                0
# 12271602                0.0                0
# 13606851                0.0                0

# %%
def transform(df, fillna=False):
    """ This version transforms includes all variables, except if 100% redundant"""
    
    # remove cod_prov only, since it is redundant with nomprov
    for col in ['cod_prov']:
        del df[col]

    # convert dates for number of days between day and base day, which is given by fecha_dato
    # will be handled as numerical int
    date_vars = ['ult_fec_cli_1t']
    df[date_vars] = df[date_vars].convert_objects(convert_dates='coerce')
    df['ult_fec_cli_1t'] = (pd.to_datetime(df['fecha_dato'])-df['ult_fec_cli_1t']).astype('timedelta64[D]')

    # removed fecha_alta - redundant with antiguedad
    # df['fecha_alta'] = (pd.to_datetime(df['fecha_dato'])-df['fecha_alta']).astype('timedelta64[D]')
    del df['fecha_alta']
    
    # convert numerical vars to int
    numerical_vars = ['age', 'antiguedad', 'renta', 'ncodpers', 'ult_fec_cli_1t']
    df[numerical_vars] = df[numerical_vars].convert_objects(convert_numeric=True)

    # convert S/N to boolean and remaining to number
    boolean_vars = ['indfall', 'ind_actividad_cliente', 'ind_nuevo', 'indresi', 'indext', 
                    'tipodom', 'conyuemp']
    for var in ['indfall', 'indresi', 'indext', 'conyuemp']:
        df[var] = df[var] == 'S'
        
    # one hot encode categorical vars
    # fecha_dato have few options, to be handled as categorical 
    categorical_vars = ['segmento', 'sexo', 'tiprel_1mes', 'canal_entrada', 'nomprov', 
                        'pais_residencia', 'ind_empleado', 'fecha_dato']
    df = pd.get_dummies(df, prefix=None, prefix_sep='_', dummy_na=False, 
                       columns=categorical_vars, sparse=False, drop_first=False)
    
    # fill na with 0
    df = df.fillna(value=0)
            
    return df

# %%
def gen_data():
    # get data
    df = pd.read_csv('train_ver2.csv', nrows=1500000)
    
    # separate the labels
    labels = []
    for col in df.columns:
        if col[:4] == 'ind_' and col[-4:] == 'ult1':
            labels.append(col)

    # create X and y delete dataframe
    X = df[df.columns.difference(labels)]
    y = df[labels].fillna(value=0) # NAs in labels will be considered 0
    del df
    
    X = transform(X)
    y = y.loc[X.index]

    # order labels, to position the most popular products in front
    ordered_labels = []
    for label in labels:
        ordered_labels.append((label, (y[label] == 1).sum()))
    labels = [x for (x,y) in sorted(ordered_labels, key=lambda x:-x[1])]    
    
    return X,y, labels

# %%
X,y, labels = gen_data()

# %% [markdown]
# ### Feature Selection

# %%
# let's do some feature selection
# In total I've got 351 features 
# most of them are categorical
# let's choose 3 labels are which more common, and work with them, to try and optimize features
for label in labels:
    print(label, y[label].sum()*1./X.shape[0])
# Out:
# ind_ahor_fin_ult1 0.000177
# ind_aval_fin_ult1 3.9e-05
# ind_cco_fin_ult1 0.749626
# ind_cder_fin_ult1 0.000591
# ind_cno_fin_ult1 0.105296
# ind_ctju_fin_ult1 0.013623
# ind_ctma_fin_ult1 0.009894
# ind_ctop_fin_ult1 0.212486
# ind_ctpp_fin_ult1 0.072079
# ind_deco_fin_ult1 0.002158
# ind_deme_fin_ult1 0.00315
# ind_dela_fin_ult1 0.066881
# ind_ecue_fin_ult1 0.106267
# ind_fond_fin_ult1 0.027182
# ind_hip_fin_ult1 0.009982
# ind_plan_fin_ult1 0.014553
# ind_pres_fin_ult1 0.004661
# ind_reca_fin_ult1 0.072581
# ind_tjcr_fin_ult1 0.066084
# ind_valo_fin_ult1 0.039378
# ind_viv_fin_ult1 0.006442
# ind_nomina_ult1 0.071242
# ind_nom_pens_ult1 0.079113
# ind_recibo_ult1 0.166275

# %% [markdown]
# One of them stand out, ind_cco_fin_ult1, 75%. Second comes ind_ctop_fin_ult1 with 21% and 3rd ind_recibo_ult1, with 17%. Let's work with these three for feature selection

# %%
label = 'ind_cco_fin_ult1'
clf = DecisionTreeClassifier()
clf.fit(X,y[label])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
# 20 most important features per decision tree
list(sorted(zip(X.columns, clf.feature_importances_), key=lambda x:-x[1]))
# Out:
# [('ncodpers', 0.23925455512523605),
#  ('renta', 0.19618125184267854),
#  ('age', 0.15566533417947886),
#  ('canal_entrada_KHE', 0.092799750530079592),
#  ('antiguedad', 0.076423282471976675),
#  ('nomprov_MADRID', 0.014343319778113714),
#  ('ind_actividad_cliente', 0.013040959612069511),
#  ('canal_entrada_KAT', 0.0093977732953335197),
#  ('nomprov_BARCELONA', 0.0090709750147857805),
#  ('sexo_V', 0.008480773190250028),
#  ('sexo_H', 0.0080663943388401896),
#  ('canal_entrada_KFC', 0.0079991961693934421),
#  ('nomprov_VALENCIA', 0.0065679641282231629),
#  ('indext', 0.0062142021669815885),
#  ('nomprov_SEVILLA', 0.0060595865209062214),
#  ('nomprov_MALAGA', 0.0047956371343746062),
#  ('fecha_dato_2015-02-28', 0.0045810236553350397),
#  ('fecha_dato_2015-01-28', 0.0044538343317748362),
#  ('segmento_02 - PARTICULARES', 0.0044413874144089783),
#  ('tiprel_1mes_A', 0.0042782212311818129),
#  ('nomprov_ZARAGOZA', 0.0042225388888579756),
#  ('canal_entrada_KFA', 0.0041101243504189202),
#  ('nomprov_ALICANTE', 0.0041052158590681662),
#  ('nomprov_CADIZ', 0.0034714078729762535),
#  ('nomprov_CORUÑA, A', 0.0034202455497763557),
#  ('nomprov_ASTURIAS', 0.0033523037606009659),
#  ('nomprov_PALMAS, LAS', 0.003151873516230658),
#  ('tiprel_1mes_I', 0.0031174951395108795),
#  ('nomprov_VALLADOLID', 0.0029912818352362215),
#  ('nomprov_BIZKAIA', 0.0028936440362495085),
#  ('nomprov_CANTABRIA', 0.0027288489596231625),
#  ('nomprov_MURCIA', 0.0026788918623924709),
#  ('nomprov_PONTEVEDRA', 0.0025883433661475354),
#  ('nomprov_GRANADA', 0.0025447014010793055),
#  ('nomprov_TOLEDO', 0.0024517699423916256),
#  ('nomprov_BALEARS, ILLES', 0.0024506229957105214),
#  ('nomprov_CORDOBA', 0.0021347206472869342),
#  ('nomprov_SANTA CRUZ DE TENERIFE', 0.0020017298992012116),
#  ('canal_entrada_KAG', 0.001933754761671009),
#  ('nomprov_TARRAGONA', 0.0018368280371160207),
#  ('nomprov_LEON', 0.0018269920496650992),
#  ('nomprov_GIPUZKOA', 0.0017724563886643316),
#  ('nomprov_CASTELLON', 0.0017468532849056811),
#  ('nomprov_NAVARRA', 0.0016877305704707036),
#  ('nomprov_GUADALAJARA', 0.0016873754962492341),
#  ('canal_entrada_KAS', 0.0016494996415819421),
#  ('nomprov_BADAJOZ', 0.0015975615734238184),
#  ('nomprov_SALAMANCA', 0.001547039559317213),
#  ('nomprov_BURGOS', 0.0015405940183799934),
#  ('nomprov_JAEN', 0.0014727035193447102),
#  ('canal_entrada_KAY', 0.0014495291882293791),
#  ('canal_entrada_KBZ', 0.0014417751138810209),
#  ('nomprov_CIUDAD REAL', 0.0014152400594461001),
#  ('nomprov_RIOJA, LA', 0.0013862517632800811),
#  ('nomprov_GIRONA', 0.0013674806254946005),
#  ('canal_entrada_KCC', 0.0013289548808428674),
#  ('canal_entrada_013', 0.0013010304439934003),
#  ('canal_entrada_KAB', 0.0012957135339191014),
#  ('segmento_03 - UNIVERSITARIO', 0.0012909048498895401),
#  ('nomprov_HUELVA', 0.0012767685748284055),
#  ('nomprov_ALMERIA', 0.0012645540716885793),
#  ('canal_entrada_KAA', 0.0012248092055270028),
#  ('nomprov_CACERES', 0.0012178955169201318),
#  ('canal_entrada_KFD', 0.0011750173369413715),
#  ('nomprov_ALBACETE', 0.0011676219987258654),
#  ('nomprov_ALAVA', 0.0010566334805788694),
#  ('nomprov_LERIDA', 0.0010471892116759908),
#  ('segmento_01 - TOP', 0.0010133207120592315),
#  ('canal_entrada_KAE', 0.0010027998236144351),
#  ('nomprov_SEGOVIA', 0.00096576437038301498),
#  ('nomprov_LUGO', 0.00084193839421905765),
#  ('indfall', 0.00082168005192540352),
#  ('canal_entrada_KAR', 0.00079001529164627552),
#  ('canal_entrada_007', 0.00075805672233921579),
#  ('nomprov_OURENSE', 0.00075569012551151193),
#  ('canal_entrada_KCI', 0.0007546797800646553),
#  ('nomprov_CUENCA', 0.0007363005982752559),
#  ('canal_entrada_KAW', 0.00073177711728978983),
#  ('canal_entrada_RED', 0.00070563582990349838),
#  ('pais_residencia_ES', 0.00070478111355280109),
#  ('nomprov_AVILA', 0.00069719739741648393),
#  ('canal_entrada_KAF', 0.00067331972498333847),
#  ('nomprov_PALENCIA', 0.00067080113412385184),
#  ('canal_entrada_KAI', 0.00062301873242052324),
#  ('nomprov_HUESCA', 0.00059846635294803102),
#  ('canal_entrada_KEY', 0.00057744411652775),
#  ('canal_entrada_KCH', 0.00057507911498657315),
#  ('canal_entrada_KAH', 0.00055991197571028336),
#  ('canal_entrada_KAZ', 0.00055208180049906705),
#  ('nomprov_ZAMORA', 0.00052863391733815035),
#  ('canal_entrada_KAQ', 0.00051081691376288023),
#  ('canal_entrada_KHD', 0.00049087241921713122),
#  ('nomprov_SORIA', 0.00041477593886106808),
#  ('canal_entrada_KAJ', 0.00039796744436019913),
#  ('indresi', 0.00036710750297326989),
#  ('canal_entrada_KAM', 0.00035152377930771701),
#  ('canal_entrada_KAD', 0.00034769276989282487),
#  ('canal_entrada_KAP', 0.00033250939607886348),
#  ('canal_entrada_KGX', 0.00032988266448607184),
#  ('nomprov_MELILLA', 0.00031967222990187842),
#  ('nomprov_CEUTA', 0.00031793692726450498),
#  ('canal_entrada_KBO', 0.00030035427109054223),
#  ('ult_fec_cli_1t', 0.00028260603717334396),
#  ('nomprov_TERUEL', 0.00027114132633331966),
#  ('canal_entrada_KDR', 0.00026579952169388606),
#  ('canal_entrada_KGV', 0.00023523991683869919),
#  ('canal_entrada_KAC', 0.00023205922836110765),
#  ('canal_entrada_KHK', 0.00023140348544466912),
#  ('canal_entrada_KAL', 0.00022350819424341592),
#  ('canal_entrada_KBH', 0.00022099233344406732),
#  ('ind_empleado_N', 0.00022025800426200425),
#  ('canal_entrada_KHC', 0.00021915302211798749),
#  ('canal_entrada_KEJ', 0.00020146689406209045),
#  ('canal_entrada_KAO', 0.00019842594089692679),
#  ('canal_entrada_KFP', 0.00018928123096720472),
#  ('canal_entrada_KCB', 0.00018861246751894592),
#  ('canal_entrada_KES', 0.00018641874987146748),
#  ('canal_entrada_KBQ', 0.00016937857332587506),
#  ('canal_entrada_KBF', 0.00016306270217240898),
#  ('canal_entrada_KFT', 0.00016230311850714638),
#  ('canal_entrada_KCG', 0.00015790101033326832),
#  ('canal_entrada_KFU', 0.00013697118297235661),
#  ('canal_entrada_KCL', 0.0001366251933963875),
#  ('indrel', 0.00013639028474727566),
#  ('canal_entrada_KFG', 0.00012847309196681547),
#  ('canal_entrada_KCM', 0.00012588142599127838),
#  ('canal_entrada_KGY', 0.00012584255749855237),
#  ('canal_entrada_KEL', 0.00012548527355228406),
#  ('pais_residencia_RO', 0.00012383436881277976),
#  ('canal_entrada_KEW', 0.00012040707126437793),
#  ('pais_residencia_AR', 0.00011885957590350255),
#  ('canal_entrada_KHF', 0.00011086118840398911),
#  ('canal_entrada_KFJ', 0.00010889766923859787),
#  ('ind_empleado_A', 0.00010841882447570118),
#  ('canal_entrada_KEI', 0.0001065707984225112),
#  ('canal_entrada_KDT', 0.00010569069347256105),
#  ('pais_residencia_CO', 0.00010537494609600952),
#  ('canal_entrada_KED', 0.00010527330818546766),
#  ('ind_empleado_B', 0.00010243715924466576),
#  ('canal_entrada_KBR', 0.00010056646612024818),
#  ('canal_entrada_KCD', 0.00010037694354188414),
#  ('canal_entrada_KFF', 9.826734462606278e-05),
#  ('canal_entrada_KBU', 9.7465680252828272e-05),
#  ('canal_entrada_KEN', 9.2913089238908875e-05),
#  ('canal_entrada_KFS', 9.2675286847898627e-05),
#  ('pais_residencia_EC', 9.1805391868793131e-05),
#  ('canal_entrada_KFK', 9.0148929634360029e-05),
#  ('pais_residencia_US', 8.9628643587201601e-05),
#  ('canal_entrada_KHL', 8.5121402264960641e-05),
#  ('pais_residencia_BR', 8.4244516779666872e-05),
#  ('canal_entrada_KAN', 8.3909423393802845e-05),
#  ('canal_entrada_KFN', 8.3695229204828596e-05),
#  ('canal_entrada_KEG', 7.3955911408338752e-05),
#  ('canal_entrada_KBG', 7.3612326055215785e-05),
#  ('canal_entrada_KEH', 7.2462128149373232e-05),
#  ('pais_residencia_MX', 7.0387243557882943e-05),
#  ('ind_empleado_F', 6.8929606463067513e-05),
#  ('pais_residencia_GB', 6.8847038479851982e-05),
#  ('pais_residencia_IT', 6.730004481211113e-05),
#  ('canal_entrada_KBW', 6.6142433808347674e-05),
#  ('pais_residencia_CL', 6.5175081809616385e-05),
#  ('canal_entrada_KFL', 6.4603498500688948e-05),
#  ('canal_entrada_KDU', 6.3484573807435395e-05),
#  ('canal_entrada_KDX', 6.3394296751558124e-05),
#  ('pais_residencia_VE', 6.2102422377152415e-05),
#  ('pais_residencia_DE', 6.1838342551685436e-05),
#  ('canal_entrada_KCA', 6.0071141654440065e-05),
#  ('pais_residencia_FR', 5.8510386028743172e-05),
#  ('canal_entrada_KDO', 5.4635875857968341e-05),
#  ('ind_nuevo', 5.4358481039281423e-05),
#  ('canal_entrada_KDC', 5.3479946518290795e-05),
#  ('canal_entrada_KAK', 5.3343578544733348e-05),
#  ('pais_residencia_CH', 5.2967026484429155e-05),
#  ('canal_entrada_KDP', 4.8995645736048868e-05),
#  ('canal_entrada_KBV', 4.5329546559112963e-05),
#  ('canal_entrada_KCN', 4.324460234305651e-05),
#  ('pais_residencia_BG', 4.2782007898833427e-05),
#  ('canal_entrada_KEZ', 4.1642444094814598e-05),
#  ('canal_entrada_KEV', 4.0022920253968064e-05),
#  ('canal_entrada_KBY', 3.94632323601307e-05),
#  ('pais_residencia_CU', 3.9053661102788717e-05),
#  ('canal_entrada_KDV', 3.8043325628250582e-05),
#  ('canal_entrada_KDS', 3.7862689037400126e-05),
#  ('pais_residencia_FI', 3.7727252349422608e-05),
#  ('canal_entrada_KBB', 3.6235500355022756e-05),
#  ('canal_entrada_KDM', 3.5662768274390495e-05),
#  ('canal_entrada_KCU', 3.5185065906453224e-05),
#  ('canal_entrada_KCK', 3.4524859675066583e-05),
#  ('canal_entrada_KDY', 3.3311868088068429e-05),
#  ('pais_residencia_BE', 3.1533423797076667e-05),
#  ('canal_entrada_KDG', 2.9710073856563452e-05),
#  ('pais_residencia_SE', 2.8825871737383504e-05),
#  ('canal_entrada_KFH', 2.8539092784913547e-05),
#  ('canal_entrada_KEK', 2.7752679579306783e-05),
#  ('canal_entrada_KDQ', 2.5503020683913817e-05),
#  ('canal_entrada_KBE', 2.5191209808754283e-05),
#  ('canal_entrada_KEA', 2.4594722120097072e-05),
#  ('canal_entrada_KCJ', 2.3479804800948073e-05),
#  ('pais_residencia_PY', 2.3306115654087703e-05),
#  ('canal_entrada_KBL', 2.3113926540429281e-05),
#  ('canal_entrada_KBJ', 2.2520794013761412e-05),
#  ('canal_entrada_KAU', 2.2003885556937665e-05),
#  ('pais_residencia_CA', 2.0952745980218131e-05),
#  ('pais_residencia_PE', 2.0333366939802592e-05),
#  ('pais_residencia_NL', 2.0140400610692403e-05),
#  ('pais_residencia_GR', 1.8733035930247406e-05),
#  ('pais_residencia_HN', 1.8256174852243964e-05),
#  ('canal_entrada_KEO', 1.7191982969135235e-05),
#  ('pais_residencia_HR', 1.6720998402543009e-05),
#  ('canal_entrada_KDE', 1.6374671391420462e-05),
#  ('canal_entrada_004', 1.6358606997703797e-05),
#  ('pais_residencia_HK', 1.6357644538890019e-05),
#  ('canal_entrada_KBS', 1.5458906199276419e-05),
#  ('canal_entrada_KGW', 1.505263669721735e-05),
#  ('canal_entrada_KHN', 1.5018253597573728e-05),
#  ('canal_entrada_KDW', 1.4983647948322743e-05),
#  ('canal_entrada_K00', 1.4945746276309809e-05),
#  ('pais_residencia_BO', 1.4852721750357287e-05),
#  ('canal_entrada_KCE', 1.4709150570745213e-05),
#  ('indrel_1mes', 1.4478856270278501e-05),
#  ('canal_entrada_KDZ', 1.4224640154365667e-05),
#  ('pais_residencia_GT', 1.3860964413899158e-05),
#  ('canal_entrada_KDA', 1.3681335994387416e-05),
#  ('pais_residencia_UY', 1.3140376343549409e-05),
#  ('canal_entrada_KEU', 1.288035625645724e-05),
#  ('canal_entrada_KBP', 1.2641946650712217e-05),
#  ('pais_residencia_IE', 1.2375650157215933e-05),
#  ('pais_residencia_IL', 1.1692955641405909e-05),
#  ('pais_residencia_LU', 1.0497462081151533e-05),
#  ('canal_entrada_KCP', 1.0394910655991251e-05),
#  ('pais_residencia_CN', 1.016006138516396e-05),
#  ('pais_residencia_ZA', 1.0123244636010931e-05),
#  ('pais_residencia_PT', 1.0058822982240262e-05),
#  ('pais_residencia_EE', 8.9708690620812107e-06),
#  ('canal_entrada_KCQ', 8.956651256904064e-06),
#  ('pais_residencia_PR', 8.824706023164149e-06),
#  ('canal_entrada_KCR', 8.8081360033478026e-06),
#  ('pais_residencia_PH', 8.7193177845763117e-06),
#  ('pais_residencia_RS', 8.5908246923608718e-06),
#  ('pais_residencia_SN', 8.4830701678754213e-06),
#  ('pais_residencia_RU', 8.4736498260055122e-06),
#  ('canal_entrada_KEC', 8.2203791029261745e-06),
#  ('canal_entrada_KFR', 8.0854783692448591e-06),
#  ('pais_residencia_AU', 8.0578133067663327e-06),
#  ('canal_entrada_KAV', 8.0330200350532207e-06),
#  ('canal_entrada_KCS', 7.9920352389560004e-06),
#  ('pais_residencia_CZ', 7.948058809127604e-06),
#  ('canal_entrada_KHM', 7.902583493040775e-06),
#  ('pais_residencia_SK', 7.8987651617798071e-06),
#  ('canal_entrada_KFM', 7.7557430903644227e-06),
#  ('pais_residencia_DO', 7.6748909834418513e-06),
#  ('canal_entrada_KBX', 7.1040313235164448e-06),
#  ('pais_residencia_GM', 7.0105572271543915e-06),
#  ('canal_entrada_KFB', 6.9180642993426901e-06),
#  ('canal_entrada_KFI', 6.8727372804251783e-06),
#  ('pais_residencia_PL', 6.8560044879760275e-06),
#  ('pais_residencia_SG', 6.7856494318832573e-06),
#  ('canal_entrada_KBM', 6.2063392379268761e-06),
#  ('canal_entrada_KEF', 6.1069742956544869e-06),
#  ('pais_residencia_UA', 5.7085965992542851e-06),
#  ('pais_residencia_SV', 5.5188202742681605e-06),
#  ('canal_entrada_KBD', 5.3280234926373336e-06),
#  ('pais_residencia_IN', 5.243882923619873e-06),
#  ('pais_residencia_PA', 5.2345493962752752e-06),
#  ('pais_residencia_CM', 4.5847866020677542e-06),
#  ('pais_residencia_CI', 4.3668064884248379e-06),
#  ('canal_entrada_KEB', 4.0028161786242574e-06),
#  ('canal_entrada_KHO', 3.9748185870139212e-06),
#  ('pais_residencia_DK', 1.7929345917306337e-06),
#  ('conyuemp', 0.0),
#  ('tipodom', 0.0),
#  ('tiprel_1mes_P', 0.0),
#  ('canal_entrada_KBN', 0.0),
#  ('canal_entrada_KCF', 0.0),
#  ('canal_entrada_KCO', 0.0),
#  ('canal_entrada_KCT', 0.0),
#  ('canal_entrada_KCV', 0.0),
#  ('canal_entrada_KCX', 0.0),
#  ('canal_entrada_KDB', 0.0),
#  ('canal_entrada_KDD', 0.0),
#  ('canal_entrada_KDF', 0.0),
#  ('canal_entrada_KDH', 0.0),
#  ('canal_entrada_KDI', 0.0),
#  ('canal_entrada_KDN', 0.0),
#  ('canal_entrada_KEE', 0.0),
#  ('canal_entrada_KEM', 0.0),
#  ('canal_entrada_KEQ', 0.0),
#  ('canal_entrada_KFE', 0.0),
#  ('canal_entrada_KFV', 0.0),
#  ('canal_entrada_KGC', 0.0),
#  ('canal_entrada_KGN', 0.0),
#  ('canal_entrada_KGU', 0.0),
#  ('canal_entrada_KHA', 0.0),
#  ('pais_residencia_AD', 0.0),
#  ('pais_residencia_AE', 0.0),
#  ('pais_residencia_AL', 0.0),
#  ('pais_residencia_AO', 0.0),
#  ('pais_residencia_AT', 0.0),
#  ('pais_residencia_BA', 0.0),
#  ('pais_residencia_BY', 0.0),
#  ('pais_residencia_BZ', 0.0),
#  ('pais_residencia_CD', 0.0),
#  ('pais_residencia_CF', 0.0),
#  ('pais_residencia_CG', 0.0),
#  ('pais_residencia_CR', 0.0),
#  ('pais_residencia_DZ', 0.0),
#  ('pais_residencia_EG', 0.0),
#  ('pais_residencia_ET', 0.0),
#  ('pais_residencia_GA', 0.0),
#  ('pais_residencia_GE', 0.0),
#  ('pais_residencia_GH', 0.0),
#  ('pais_residencia_GI', 0.0),
#  ('pais_residencia_GN', 0.0),
#  ('pais_residencia_GQ', 0.0),
#  ('pais_residencia_GW', 0.0),
#  ('pais_residencia_HU', 0.0),
#  ('pais_residencia_IS', 0.0),
#  ('pais_residencia_JP', 0.0),
#  ('pais_residencia_KE', 0.0),
#  ('pais_residencia_KH', 0.0),
#  ('pais_residencia_KR', 0.0),
#  ('pais_residencia_KW', 0.0),
#  ('pais_residencia_KZ', 0.0),
#  ('pais_residencia_LB', 0.0),
#  ('pais_residencia_LT', 0.0),
#  ('pais_residencia_LV', 0.0),
#  ('pais_residencia_LY', 0.0),
#  ('pais_residencia_MA', 0.0),
#  ('pais_residencia_MD', 0.0),
#  ('pais_residencia_MK', 0.0),
#  ('pais_residencia_ML', 0.0),
#  ('pais_residencia_MM', 0.0),
#  ('pais_residencia_MR', 0.0),
#  ('pais_residencia_MZ', 0.0),
#  ('pais_residencia_NG', 0.0),
#  ('pais_residencia_NI', 0.0),
#  ('pais_residencia_NO', 0.0),
#  ('pais_residencia_NZ', 0.0),
#  ('pais_residencia_OM', 0.0),
#  ('pais_residencia_PK', 0.0),
#  ('pais_residencia_QA', 0.0),
#  ('pais_residencia_SA', 0.0),
#  ('pais_residencia_SL', 0.0),
#  ('pais_residencia_TG', 0.0),
#  ('pais_residencia_TH', 0.0),
#  ('pais_residencia_TN', 0.0),
#  ('pais_residencia_TR', 0.0),
#  ('pais_residencia_TW', 0.0),
#  ('pais_residencia_VN', 0.0),
#  ('ind_empleado_S', 0.0)]

# %%
# 20 most important features per selectKbest, and their p-value which is relevant
selector = SelectKBest(k=20)
selector.fit(X,y[label])
list(sorted(zip(X.columns, selector.scores_, selector.pvalues_), key=lambda x:-x[1]))
# Out:
# [('canal_entrada_KHE', 102292.26125632203, 0.0),
#  ('segmento_03 - UNIVERSITARIO', 90490.039558362623, 0.0),
#  ('ncodpers', 66156.704967162485, 0.0),
#  ('segmento_02 - PARTICULARES', 45668.446242552563, 0.0),
#  ('canal_entrada_KAT', 17901.791005238305, 0.0),
#  ('nomprov_MADRID', 17601.747192783132, 0.0),
#  ('age', 17054.519040127234, 0.0),
#  ('tiprel_1mes_I', 16133.508427903529, 0.0),
#  ('tiprel_1mes_A', 10981.050792527869, 0.0),
#  ('tipodom', 10746.601898096182, 0.0),
#  ('indrel_1mes', 10380.216892595772, 0.0),
#  ('ind_empleado_N', 10158.619892102673, 0.0),
#  ('fecha_dato_2015-01-28', 8275.1779209089727, 0.0),
#  ('fecha_dato_2015-02-28', 8275.1779209089727, 0.0),
#  ('segmento_01 - TOP', 6369.3679074336787, 0.0),
#  ('indresi', 6146.5951201432099, 0.0),
#  ('pais_residencia_ES', 6146.5951201432099, 0.0),
#  ('canal_entrada_KFC', 5225.4327914087053, 0.0),
#  ('ind_actividad_cliente', 3002.5331821983145, 0.0),
#  ('nomprov_MURCIA', 2814.1093240785149, 0.0),
#  ('canal_entrada_KFA', 2199.8561237798317, 0.0),
#  ('sexo_H', 2020.8798172538268, 0.0),
#  ('nomprov_CORUÑA, A', 1854.4469773529986, 0.0),
#  ('canal_entrada_KHD', 1588.0935816136005, 0.0),
#  ('nomprov_BADAJOZ', 1399.2568873078853, 4.9727125092045434e-306),
#  ('canal_entrada_013', 1385.8153631557363, 4.1059578397526072e-303),
#  ('canal_entrada_KAS', 1120.7693709974328, 1.3846568417595533e-245),
#  ('nomprov_PONTEVEDRA', 1057.0687286629527, 9.3623379196885755e-232),
#  ('nomprov_CACERES', 1045.6357631519663, 2.8429438773830746e-229),
#  ('nomprov_HUELVA', 766.11677278994887, 1.4552697903210514e-168),
#  ('nomprov_CADIZ', 662.38334653652862, 5.0556339091149542e-146),
#  ('nomprov_SALAMANCA', 648.94949752630498, 4.2016543527721541e-143),
#  ('nomprov_LUGO', 605.34731312600582, 1.2607414490264784e-133),
#  ('nomprov_ALBACETE', 583.49165243938785, 7.1065147097573777e-129),
#  ('nomprov_MALAGA', 578.67252866941351, 7.9305272558067899e-128),
#  ('sexo_V', 543.10859393154669, 4.2785825378438877e-120),
#  ('nomprov_OURENSE', 534.31187782632435, 3.4993310680058508e-118),
#  ('canal_entrada_KAY', 463.38924004708753, 9.2842585257564517e-103),
#  ('renta', 459.49763471528195, 6.5197577086074196e-102),
#  ('nomprov_CORDOBA', 441.58936058200629, 5.1262886749426391e-98),
#  ('nomprov_CIUDAD REAL', 415.05961130485258, 3.0309907849459885e-92),
#  ('nomprov_ASTURIAS', 388.69552418613483, 1.6532870060846929e-86),
#  ('canal_entrada_KEY', 361.86642139826205, 1.1414882055106562e-80),
#  ('nomprov_SEVILLA', 349.71927802748746, 5.0306320685532578e-78),
#  ('nomprov_CUENCA', 348.4764123890065, 9.3795428552777301e-78),
#  ('nomprov_GRANADA', 337.76078947003913, 2.0183304964189651e-75),
#  ('nomprov_LERIDA', 301.49711317965631, 1.5905095503145267e-67),
#  ('nomprov_ZAMORA', 273.55781753165792, 1.939544115737796e-61),
#  ('nomprov_VALLADOLID', 246.54024172680508, 1.4975127242733829e-55),
#  ('canal_entrada_KHF', 239.40905436439016, 5.3682492783439029e-54),
#  ('canal_entrada_KAG', 233.44565332116392, 1.0712562710335528e-52),
#  ('nomprov_TOLEDO', 216.21525045969094, 6.1247410635933071e-49),
#  ('canal_entrada_KHK', 204.63372673588125, 2.0572901281658339e-46),
#  ('canal_entrada_KEW', 202.18038617383343, 7.0553206661829244e-46),
#  ('nomprov_PALENCIA', 185.21706203692315, 3.5495715438742585e-42),
#  ('canal_entrada_KBZ', 139.79663145638082, 2.9637249016746085e-32),
#  ('nomprov_ALICANTE', 136.19463041759118, 1.8175350748606163e-31),
#  ('canal_entrada_KAE', 132.50809309416135, 1.1635072107606674e-30),
#  ('canal_entrada_KAM', 132.19849754013921, 1.3598420834931568e-30),
#  ('canal_entrada_KAB', 130.98716215921115, 2.50300286759625e-30),
#  ('canal_entrada_KAA', 130.76833579589777, 2.7946687800060608e-30),
#  ('canal_entrada_KAZ', 125.32219718023093, 4.3440021720462239e-29),
#  ('canal_entrada_007', 124.29503184352006, 7.2889950663136834e-29),
#  ('canal_entrada_KAF', 123.70836025861746, 9.7961915933648059e-29),
#  ('nomprov_GIRONA', 119.03153657142967, 1.0344947826714124e-27),
#  ('canal_entrada_KAC', 109.75687506260505, 1.1111754062201956e-25),
#  ('nomprov_BURGOS', 102.10024658377363, 5.2922392651338508e-24),
#  ('canal_entrada_KGY', 97.915972234708875, 4.3758725528916084e-23),
#  ('canal_entrada_KAD', 85.78011571499664, 2.0147701647174481e-20),
#  ('canal_entrada_KGV', 81.86388293983191, 1.460396478744129e-19),
#  ('nomprov_TERUEL', 80.053951131572717, 3.6492356601508069e-19),
#  ('nomprov_CASTELLON', 79.446433381682525, 4.9628042480819796e-19),
#  ('ind_empleado_A', 78.808535001981483, 6.8539796449942958e-19),
#  ('canal_entrada_KBO', 73.530444890341229, 9.9233494197552829e-18),
#  ('nomprov_AVILA', 72.76871819150989, 1.4596748533448076e-17),
#  ('pais_residencia_RO', 72.039364132337582, 2.1122850313601792e-17),
#  ('canal_entrada_KEJ', 68.225611683558455, 1.4599415402847298e-16),
#  ('nomprov_GUADALAJARA', 68.087060936871026, 1.5662050830990932e-16),
#  ('canal_entrada_KCI', 67.216900303072478, 2.4350317868684304e-16),
#  ('canal_entrada_KFP', 67.013366746975038, 2.6998435180537514e-16),
#  ('nomprov_PALMAS, LAS', 64.719157617983171, 8.6464284366086312e-16),
#  ('nomprov_VALENCIA', 64.507208324868756, 9.6283025195726889e-16),
#  ('canal_entrada_KHL', 62.010709759768332, 3.4193349290232626e-15),
#  ('canal_entrada_KFD', 60.891601903929299, 6.0363298613045504e-15),
#  ('canal_entrada_KCC', 60.73487312354635, 6.5365210894350594e-15),
#  ('nomprov_HUESCA', 60.349039716958224, 7.951804821576553e-15),
#  ('canal_entrada_KFG', 60.106943563570432, 8.9924706570697807e-15),
#  ('canal_entrada_KDX', 58.285289837984294, 2.2693231106153826e-14),
#  ('canal_entrada_KAR', 56.678224588016938, 5.1371488040424966e-14),
#  ('tiprel_1mes_P', 55.875003818477907, 7.729069243069216e-14),
#  ('canal_entrada_KDR', 55.358211040521404, 1.0052913575447079e-13),
#  ('canal_entrada_KCB', 54.785074358947512, 1.3456262101174043e-13),
#  ('nomprov_ZARAGOZA', 54.026952617067877, 1.9790786380983943e-13),
#  ('nomprov_BIZKAIA', 50.88409148949389, 9.8050452500450678e-13),
#  ('indfall', 48.540598170142424, 3.237200168837532e-12),
#  ('canal_entrada_KFK', 47.297012783020961, 6.1040672803135351e-12),
#  ('canal_entrada_KCL', 46.891771953096594, 7.5059990711487892e-12),
#  ('nomprov_CANTABRIA', 46.039597277894337, 1.1595092947379673e-11),
#  ('canal_entrada_KDY', 45.869749703593257, 1.2645190294340776e-11),
#  ('canal_entrada_KFF', 45.844682694736171, 1.2808030624882492e-11),
#  ('canal_entrada_KGX', 44.117678213664163, 3.0937292656778782e-11),
#  ('canal_entrada_KAU', 42.757654734414828, 6.1988593315532342e-11),
#  ('canal_entrada_KAI', 37.600787582534238, 8.6841725293296215e-10),
#  ('nomprov_NAVARRA', 35.426508380227013, 2.6494533220229588e-09),
#  ('canal_entrada_KAW', 35.197585441132333, 2.9799012322746647e-09),
#  ('canal_entrada_KAN', 34.788814866283438, 3.6759615287646734e-09),
#  ('canal_entrada_KAH', 34.684118528588861, 3.8790553665847246e-09),
#  ('ind_nuevo', 34.316967891396189, 4.6842701202916545e-09),
#  ('canal_entrada_KCG', 33.790090386100438, 6.1409331961334108e-09),
#  ('canal_entrada_KBR', 30.738144601063173, 2.9537676965736438e-08),
#  ('canal_entrada_KDC', 30.56797059162998, 3.2245215964986257e-08),
#  ('canal_entrada_KEH', 30.450919416363138, 3.4250553354550045e-08),
#  ('canal_entrada_KDS', 28.611555769484575, 8.8472095314608498e-08),
#  ('canal_entrada_KCM', 28.51750540949774, 9.2875343989734245e-08),
#  ('canal_entrada_KCD', 27.077334224861367, 1.9551494182415934e-07),
#  ('canal_entrada_004', 26.677408763844902, 2.404619959475224e-07),
#  ('canal_entrada_KBQ', 25.319101109105748, 4.8595731549472118e-07),
#  ('canal_entrada_KFS', 23.915372464868238, 1.0068029576066571e-06),
#  ('canal_entrada_KHC', 23.812991397493409, 1.0617979769890141e-06),
#  ('canal_entrada_KEZ', 23.722073542967991, 1.1131561890169413e-06),
#  ('canal_entrada_KCN', 22.435729434877047, 2.1732368278878604e-06),
#  ('canal_entrada_KBW', 21.98247447257534, 2.7518772587846669e-06),
#  ('canal_entrada_KCH', 21.351093789081823, 3.824501155075001e-06),
#  ('canal_entrada_KHN', 21.26547168481536, 3.9991911320470063e-06),
#  ('canal_entrada_KBU', 20.862695517501315, 4.9346972437889119e-06),
#  ('canal_entrada_KFT', 19.95005996996084, 7.9500150374772772e-06),
#  ('canal_entrada_KEI', 19.942740678911061, 7.9805066259264997e-06),
#  ('pais_residencia_GR', 19.784785976004599, 8.6679136369493532e-06),
#  ('pais_residencia_GB', 19.758063808484636, 8.7899513390510476e-06),
#  ('canal_entrada_KDG', 18.989676907389644, 1.314406574608818e-05),
#  ('nomprov_ALAVA', 18.724322835263827, 1.5105814465200464e-05),
#  ('pais_residencia_FR', 18.649377412191591, 1.5711366232955193e-05),
#  ('pais_residencia_CO', 15.924133868724672, 6.5937323659626893e-05),
#  ('canal_entrada_KBF', 15.87613587326093, 6.7630873913394031e-05),
#  ('canal_entrada_KED', 15.87613587326093, 6.7630873913394031e-05),
#  ('indext', 15.669734875100895, 7.542664602661883e-05),
#  ('antiguedad', 15.487430382002039, 8.3061339135738369e-05),
#  ('canal_entrada_KEB', 15.377999733543616, 8.8012883190477319e-05),
#  ('pais_residencia_EC', 15.108260257561696, 0.00010152465205752298),
#  ('canal_entrada_KBH', 14.904485034419467, 0.00011310089441355393),
#  ('canal_entrada_KFL', 14.685690274282006, 0.00012701466912722249),
#  ('canal_entrada_KDP', 14.660010274323666, 0.00012875688673091829),
#  ('canal_entrada_KCU', 14.305317850459092, 0.00015543421901137273),
#  ('canal_entrada_KFJ', 14.274796308126454, 0.00015797505666002707),
#  ('canal_entrada_KCK', 14.253446327769115, 0.00015977720987773083),
#  ('canal_entrada_KHM', 14.176710501262269, 0.00016642715524265632),
#  ('canal_entrada_KDU', 13.724222136320943, 0.00021171781442101605),
#  ('canal_entrada_KBB', 13.122771105940567, 0.00029174264575993039),
#  ('pais_residencia_DE', 12.603053411359143, 0.00038513477052592402),
#  ('nomprov_TARRAGONA', 12.464797413715237, 0.00041471212416407851),
#  ('canal_entrada_KAK', 12.406848930728399, 0.00042778111600245912),
#  ('canal_entrada_KAO', 12.211071819641862, 0.00047508787106077685),
#  ('pais_residencia_NL', 12.192496112089422, 0.00047984204752758551),
#  ('nomprov_SANTA CRUZ DE TENERIFE',
#   12.092002574057934,
#   0.00050640706376630295),
#  ('pais_residencia_RS', 11.976267136605825, 0.00053884660663702224),
#  ('canal_entrada_KDV', 11.952760690620547, 0.0005456873630654682),
#  ('canal_entrada_KAP', 11.907886749671542, 0.00055899083098240451),
#  ('pais_residencia_CH', 11.597217557855926, 0.00066053161485194714),
#  ('ind_empleado_F', 11.442129831967463, 0.00071800198495474343),
#  ('canal_entrada_KDT', 10.676759637431847, 0.0010849359311874327),
#  ('pais_residencia_HR', 10.640288557027615, 0.0011065411303633221),
#  ('pais_residencia_MX', 10.070512093606322, 0.001506657098278977),
#  ('nomprov_SEGOVIA', 9.7872811923952607, 0.0017572813522559753),
#  ('canal_entrada_KFU', 9.6889981920825274, 0.0018537980449564193),
#  ('canal_entrada_KAQ', 9.0701174805067364, 0.0025982686524454795),
#  ('pais_residencia_HN', 9.0243325215276613, 0.0026641578159471027),
#  ('canal_entrada_KBD', 8.9323561099000237, 0.0028016951541485107),
#  ('canal_entrada_KEA', 8.8408211781324244, 0.0029457359765528773),
#  ('canal_entrada_KDQ', 8.7748704708353493, 0.0030541602592976786),
#  ('pais_residencia_JP', 8.6842462387299904, 0.0032097970093776934),
#  ('canal_entrada_KCP', 8.3053070748417088, 0.0039530239378614612),
#  ('canal_entrada_KBJ', 8.2640732047385441, 0.0040438151584065649),
#  ('ind_empleado_B', 8.002940535885406, 0.004670237666769955),
#  ('canal_entrada_KFE', 7.3481691447004014, 0.0067132231752481007),
#  ('nomprov_SORIA', 6.9492558940672788, 0.0083855399358451488),
#  ('pais_residencia_US', 6.8768272688268626, 0.008732175790650663),
#  ('nomprov_RIOJA, LA', 6.6532541805249776, 0.0098976310737772868),
#  ('canal_entrada_KDM', 6.3181986459883905, 0.011950652771784854),
#  ('canal_entrada_KGW', 6.1754453802361198, 0.012953692065394999),
#  ('canal_entrada_KFR', 6.0181792100418718, 0.014159416917729649),
#  ('conyuemp', 5.9880857344111966, 0.014402994940258866),
#  ('canal_entrada_KCT', 5.9880857344111966, 0.014402994940258866),
#  ('canal_entrada_KDB', 5.9880857344111966, 0.014402994940258866),
#  ('canal_entrada_KHO', 5.9880857344111966, 0.014402994940258866),
#  ('pais_residencia_GE', 5.9880857344111966, 0.014402994940258866),
#  ('pais_residencia_GH', 5.9880857344111966, 0.014402994940258866),
#  ('pais_residencia_GM', 5.9880857344111966, 0.014402994940258866),
#  ('pais_residencia_KW', 5.9880857344111966, 0.014402994940258866),
#  ('pais_residencia_LB', 5.9880857344111966, 0.014402994940258866),
#  ('pais_residencia_TN', 5.9880857344111966, 0.014402994940258866),
#  ('ind_empleado_S', 5.9880857344111966, 0.014402994940258866),
#  ('nomprov_CEUTA', 5.9860488274957762, 0.014419636788231213),
#  ('canal_entrada_KBL', 5.9644953502594982, 0.014596949623649078),
#  ('pais_residencia_MA', 5.9501036336240292, 0.01471659352836756),
#  ('pais_residencia_IT', 5.8150493598032957, 0.015889786460237428),
#  ('pais_residencia_VE', 5.6897435456992671, 0.017064533244659348),
#  ('nomprov_JAEN', 5.6200978293435364, 0.017755846188162967),
#  ('pais_residencia_AE', 5.5701227340815374, 0.018269671040190442),
#  ('canal_entrada_KEG', 5.3844240395034593, 0.020317494026056346),
#  ('nomprov_MELILLA', 5.360593298255762, 0.020596966650427796),
#  ('canal_entrada_KBE', 5.3121965603934838, 0.021176844132442155),
#  ('indrel', 5.1859498527619508, 0.0227704327312785),
#  ('pais_residencia_CZ', 5.1032412121585233, 0.023881393534780446),
#  ('canal_entrada_KDE', 4.993053326982726, 0.025449484916190011),
#  ('canal_entrada_KEK', 4.993053326982726, 0.025449484916190011),
#  ('canal_entrada_KEC', 4.8864073155596461, 0.027069183967804365),
#  ('pais_residencia_CN', 4.787158850341668, 0.028672915028685547),
#  ('pais_residencia_NO', 4.3420478170415935, 0.037182429666765777),
#  ('pais_residencia_AR', 4.2155822921850827, 0.0400545759195697),
#  ('pais_residencia_AT', 4.1948658712900455, 0.040546821139127311),
#  ('canal_entrada_KBV', 4.0204884340957268, 0.044950962662871088),
#  ('canal_entrada_KAJ', 4.0194134864684088, 0.044979622023550409),
#  ('pais_residencia_KR', 4.008038791996948, 0.045284066532350092),
#  ('canal_entrada_KBX', 3.9841261923247493, 0.045931188989691868),
#  ('pais_residencia_CU', 3.8434541755561122, 0.049940814144118842),
#  ('pais_residencia_BG', 3.759453457966448, 0.052510020400663694),
#  ('canal_entrada_KCA', 3.5511838803446332, 0.059503271443024981),
#  ('canal_entrada_KCJ', 3.5361824022310713, 0.060043799183677457),
#  ('pais_residencia_KE', 3.340023415348659, 0.067613944634144163),
#  ('pais_residencia_MD', 3.340023415348659, 0.067613944634144163),
#  ('pais_residencia_PK', 3.340023415348659, 0.067613944634144163),
#  ('pais_residencia_CI', 3.2564641067267432, 0.071142677662757378),
#  ('pais_residencia_HK', 3.2564641067267432, 0.071142677662757378),
#  ('nomprov_BARCELONA', 3.1661112355191259, 0.075181559533665676),
#  ('canal_entrada_K00', 3.0885686624054269, 0.078844439625229468),
#  ('canal_entrada_KEO', 2.8603915768469599, 0.090785707281431316),
#  ('canal_entrada_KFV', 2.7700432127453838, 0.096043881639263862),
#  ('canal_entrada_KHA', 2.7700432127453838, 0.096043881639263862),
#  ('pais_residencia_EE', 2.7700432127453838, 0.096043881639263862),
#  ('pais_residencia_PY', 2.7311497993123726, 0.098408727765248394),
#  ('pais_residencia_AO', 2.6720116032645955, 0.10212718256297051),
#  ('pais_residencia_EG', 2.6720116032645955, 0.10212718256297051),
#  ('canal_entrada_KDA', 2.4964555194681339, 0.11410315915385481),
#  ('canal_entrada_KCV', 2.3686629806088306, 0.12379335195604563),
#  ('canal_entrada_KBY', 2.3276965945273553, 0.1270901280578324),
#  ('pais_residencia_UY', 2.2401162570495283, 0.13447118501076016),
#  ('canal_entrada_KBG', 2.1706776280627049, 0.14066455391300225),
#  ('canal_entrada_KEV', 2.1559894512894804, 0.14201524718387626),
#  ('pais_residencia_BR', 2.0634597297379189, 0.15086760673051219),
#  ('pais_residencia_DK', 2.0100310416664158, 0.15626243220366601),
#  ('pais_residencia_GN', 2.0040033557162298, 0.15688468553643078),
#  ('pais_residencia_NZ', 2.0040033557162298, 0.15688468553643078),
#  ('pais_residencia_RU', 1.7488246772252776, 0.18602485731543991),
#  ('canal_entrada_KEN', 1.7129611362676047, 0.19060192909935258),
#  ('pais_residencia_GA', 1.670000568634016, 0.19625875671164197),
#  ('pais_residencia_MR', 1.670000568634016, 0.19625875671164197),
#  ('pais_residencia_FI', 1.5950502154021471, 0.20660637457920325),
#  ('canal_entrada_KAL', 1.5380036034005091, 0.21491550033884083),
#  ('pais_residencia_CA', 1.5142532496728096, 0.21849151280618972),
#  ('pais_residencia_BE', 1.4158158004539907, 0.23409361368220122),
#  ('canal_entrada_KCX', 1.3359986726750281, 0.24774112076438226),
#  ('pais_residencia_CG', 1.3359986726750281, 0.24774112076438226),
#  ('pais_residencia_GW', 1.3359986726750281, 0.24774112076438226),
#  ('pais_residencia_LT', 1.3359986726750281, 0.24774112076438226),
#  ('pais_residencia_NI', 1.3359986726750281, 0.24774112076438226),
#  ('pais_residencia_VN', 1.3359986726750281, 0.24774112076438226),
#  ('canal_entrada_KFH', 1.3305171070587021, 0.24871352025229268),
#  ('pais_residencia_BA', 1.3280279123542154, 0.24915663270235422),
#  ('pais_residencia_PH', 1.3280279123542154, 0.24915663270235422),
#  ('nomprov_LEON', 1.3127783768312686, 0.25189250454401974),
#  ('pais_residencia_UA', 1.2996500240563336, 0.25427743343202941),
#  ('canal_entrada_KEU', 1.2907903039270632, 0.2559026308143823),
#  ('pais_residencia_IL', 1.2636474098568493, 0.26096208281438055),
#  ('canal_entrada_KBM', 1.2227260825657675, 0.2688265857547798),
#  ('canal_entrada_KBP', 1.1928456617657093, 0.27475656605507442),
#  ('canal_entrada_KFB', 1.1928456617657093, 0.27475656605507442),
#  ('pais_residencia_SK', 1.1928456617657093, 0.27475656605507442),
#  ('canal_entrada_KDF', 1.1114732442933539, 0.29176217642497887),
#  ('nomprov_GIPUZKOA', 1.0766519102441094, 0.29944800633170077),
#  ('pais_residencia_SE', 1.0667744354301969, 0.3016754121632213),
#  ('pais_residencia_ET', 1.0019976678356988, 0.31682785499238619),
#  ('pais_residencia_MZ', 1.0019976678356988, 0.31682785499238619),
#  ('pais_residencia_QA', 1.0019976678356988, 0.31682785499238619),
#  ('pais_residencia_TW', 1.0019976678356988, 0.31682785499238619),
#  ('canal_entrada_RED', 0.95184509519788174, 0.32925032515848596),
#  ('pais_residencia_DO', 0.94808220421602918, 0.33020817275601155),
#  ('pais_residencia_NG', 0.89601304003616866, 0.34385324532710571),
#  ('canal_entrada_KDW', 0.8681735352050074, 0.35146167357834268),
#  ('pais_residencia_ZA', 0.86228905694719205, 0.35309913190806097),
#  ('canal_entrada_KES', 0.79376250414473659, 0.37296506113407701),
#  ('nomprov_BALEARS, ILLES', 0.75943406206806263, 0.38350589931178325),
#  ('pais_residencia_SV', 0.7518553467573974, 0.38588966070265707),
#  ('nomprov_ALMERIA', 0.68879699099543223, 0.40657406898976522),
#  ('canal_entrada_KFM', 0.67401818300171024, 0.4116543797454576),
#  ('canal_entrada_KBN', 0.66799755411246153, 0.41375081840614436),
#  ('canal_entrada_KDI', 0.66799755411246153, 0.41375081840614436),
#  ('canal_entrada_KGU', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_BZ', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_CD', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_CF', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_GI', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_HU', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_IS', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_KH', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_KZ', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_LV', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_LY', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_ML', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_MM', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_OM', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_SL', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_TG', 0.66799755411246153, 0.41375081840614436),
#  ('pais_residencia_IE', 0.66690502294696175, 0.41413293750020053),
#  ('canal_entrada_KEE', 0.66004930541667906, 0.41654273112128126),
#  ('canal_entrada_KEF', 0.66004930541667906, 0.41654273112128126),
#  ('canal_entrada_KFI', 0.48576522363884578, 0.48582260978434488),
#  ('canal_entrada_KCE', 0.45513142087874831, 0.4999083002556638),
#  ('pais_residencia_AU', 0.45202945118811771, 0.50137292851538229),
#  ('pais_residencia_PL', 0.44827416688647015, 0.50315582147215743),
#  ('canal_entrada_KCO', 0.44800094316517697, 0.50328596145602245),
#  ('canal_entrada_KEQ', 0.44800094316517697, 0.50328596145602245),
#  ('pais_residencia_BY', 0.44800094316517697, 0.50328596145602245),
#  ('pais_residencia_TH', 0.44800094316517697, 0.50328596145602245),
#  ('canal_entrada_KAV', 0.44003013323366619, 0.50710806507696948),
#  ('canal_entrada_KDH', 0.44003013323366619, 0.50710806507696948),
#  ('pais_residencia_AD', 0.44003013323366619, 0.50710806507696948),
#  ('pais_residencia_GT', 0.44003013323366619, 0.50710806507696948),
#  ('ult_fec_cli_1t', 0.40756648564534198, 0.52320739910580105),
#  ('pais_residencia_BO', 0.40732190244240557, 0.52333208778407703),
#  ('canal_entrada_KEL', 0.40713145915508686, 0.52342921247152763),
#  ('canal_entrada_KCF', 0.40561368390894059, 0.52420441060327172),
#  ('canal_entrada_KFN', 0.35046870894502674, 0.55384805945069149),
#  ('canal_entrada_KDZ', 0.34664829945324399, 0.55601673968582277),
#  ('canal_entrada_KGC', 0.33399833150175084, 0.56331428726465138),
#  ('canal_entrada_KGN', 0.33399833150175084, 0.56331428726465138),
#  ('pais_residencia_AL', 0.33399833150175084, 0.56331428726465138),
#  ('pais_residencia_CM', 0.33002157354327966, 0.56564651467131011),
#  ('pais_residencia_PR', 0.27545552083054958, 0.59969553560488031),
#  ('canal_entrada_KCS', 0.26243551103157525, 0.60845195542796748),
#  ('pais_residencia_IN', 0.26243551103157525, 0.60845195542796748),
#  ('pais_residencia_MK', 0.22001369811179708, 0.63902958390890507),
#  ('pais_residencia_TR', 0.22001369811179708, 0.63902958390890507),
#  ('pais_residencia_CL', 0.1894640877746987, 0.66336312157859512),
#  ('pais_residencia_PA', 0.13520182062446717, 0.71309850865456692),
#  ('pais_residencia_SG', 0.097147566327762919, 0.75527996079169368),
#  ('pais_residencia_GQ', 0.093162156171798363, 0.76019503700329738),
#  ('pais_residencia_LU', 0.093162156171798363, 0.76019503700329738),
#  ('canal_entrada_KDO', 0.092386702988819902, 0.76116466840533081),
#  ('canal_entrada_KDN', 0.076007643701741789, 0.78278251787590458),
#  ('canal_entrada_KCQ', 0.0625560531077511, 0.80250072497935443),
#  ('canal_entrada_KCR', 0.058570611343527514, 0.80876962893961879),
#  ('pais_residencia_SA', 0.046580749846269018, 0.82912362823616537),
#  ('pais_residencia_SN', 0.046580749846269018, 0.82912362823616537),
#  ('pais_residencia_PT', 0.041098680245364019, 0.83934760443614032),
#  ('pais_residencia_PE', 0.030754289549697538, 0.86078972540948129),
#  ('canal_entrada_KBS', 0.022715520549187164, 0.88019923748391615),
#  ('pais_residencia_CR', 0.0212152126804733, 0.88419422746742404),
#  ('canal_entrada_KDD', 1.7886696244647512e-05, 0.99662553764760387),
#  ('canal_entrada_KEM', 5.9621366861309822e-06, 0.99805177356595098),
#  ('pais_residencia_DZ', 5.9621366861309822e-06, 0.99805177356595098)]

# %% [markdown]
# There are a lot of coincidences between both lists. In the categorical variables, we have canal_entrada_KHE, segmento Universitarios. In the numerical variables, there is age, ncodepers ( a sequential id that will tell which customer came before) and antiguedad, which is also represented by fecha_alta and fecha_alta_month (redundancy to be removed). For the big categorical variables, we can see that province > canal_entrada > country of residence.

# %% [markdown]
# ### Benchmark

# %%
# assign all 0s and 1s, and check accuracy
# benchmark

label = 'ind_cco_fin_ult1'
pred0 = np.zeros(y.shape[0])
pred1 = np.zeros(y.shape[0])

print("Accuracy all 1s: {:.2f}".format(accuracy_score(y[label], pred1)))
print("Accuracy all 0s: {:.2f}".format(accuracy_score(y[label], pred0)))

y[label].value_counts()
# Out:
# Accuracy all 1s: 0.25
# Accuracy all 0s: 0.25
# 1    749626
# 0    250374
# Name: ind_cco_fin_ult1, dtype: int64

# %% [markdown]
# ### Results with and without feature selection

# %% [markdown]
# Let's try predict with and without feature selection to get a general understanding whether it will help the classifier or not

# %%
# without:
clf = DecisionTreeClassifier()
score = cross_val_score(clf, X, y[label])
print("Mean score: {:.2f}, Std: {:.2f}".format(score.mean(), score.std()))
# Out:
# Mean score: 0.53, Std: 0.16

# %%
# with:
label = 'ind_cco_fin_ult1'
for i in range(1,10,2):
    selector = SelectKBest(k=i)
    X_selected = selector.fit_transform(X, y[label])
    clf = DecisionTreeClassifier()
    score = cross_val_score(clf, X_selected, y[label])
    print("{} features: Mean score: {:.2f}, Std: {:.2f}".format(i, score.mean(), score.std()))
# Out:
# 1 features: Mean score: 0.75, Std: 0.00
# 3 features: Mean score: 0.90, Std: 0.07
# 5 features: Mean score: 0.90, Std: 0.07
# 7 features: Mean score: 0.90, Std: 0.07
# 9 features: Mean score: 0.90, Std: 0.07

# %% [markdown]
# Less features makes a huge difference in the results. The problem is for each product, we might deal with different features. So it is best to select them before training each classifier.
#
# It seems 3 features are enough to drive accuracy to 90%. Performance starts to drop after 12 features. This should reflect on the feature transformation as well - most of the variabiity will be encoded in a few components.

# %% [markdown]
# ### Feature Transformation

# %% [markdown]
# Instead of selecting features, let's try to use as most as possible by transforming the features into principal components and capturing their variability in a small number of features.
#
# First we will need to scale the features, then apply a principal component analysis and extract the main features. We will aim at getting the components that explain up to 80% in the variability.

# %%
# scaling
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=20)
X_pc = pca.fit_transform(X_scaled, y[label])

# Can I get a good model with 12 components, or 80% explained variance?
clf = DecisionTreeClassifier()
score = cross_val_score(clf, X_pc, y[label])
print("Mean score: {:.2f}, Std: {:.2f}".format(score.mean(), score.std()))
# Out:
# Mean score: 0.46, Std: 0.19

# %%
for i in range(1,10):
    print(i, pca.explained_variance_ratio_[:i].sum())
# Out:
# 1 0.240505022952
# 2 0.373810519771
# 3 0.490166483124
# 4 0.580849256425
# 5 0.653848257105
# 6 0.705532844255
# 7 0.73015535148
# 8 0.751299274439
# 9 0.770741410394

# %%
# try different number of components
for i in [2,5,10,50,100]:
    
    pca = PCA(n_components=i)
    X_pc = pca.fit_transform(X_scaled, y[label])

    clf = DecisionTreeClassifier()
    score = cross_val_score(clf, X_pc, y[label])
    print("Mean score: {:.2f}, Std: {:.2f}".format(score.mean(), score.std()))
# Out:
# Mean score: 0.50, Std: 0.17
# Mean score: 0.46, Std: 0.19
# Mean score: 0.47, Std: 0.19
# Mean score: 0.48, Std: 0.19
# Mean score: 0.47, Std: 0.19

# %% [markdown]
# ### Predicting with feature selection in pipeline

# %% [markdown]
# After all required corvertions have been made, I can make a first shot at predicting. First question we need to ask is, what I'm a predicting?
#
# I'm predicting comsuption of a certain product. I have a total of 24 booleans that will tell whether or not this customer consumed this product. These are my labels for a One vs All classification model.

# %%
X,y,labels=gen_data()

# %%
# upload test data
X_test = pd.read_csv('test_ver2.csv')

# initialize results
report = pd.DataFrame(X_test['ncodpers'])
classif_results = {}

# prepare test data for classifer
X_test = transform(X_test, fillna=True)

# %%
# X_test should only have columns that are also in X (needed due to one-hot encoding)
paired_columns = list(set(X_test.columns).intersection(X.columns))
X_test = X_test[paired_columns]
X = X[paired_columns]

# %%
# predict each product with a different clssifer
for label in labels:
    if len(y[label].value_counts()) != 1:
        # select 6 features
        selector = SelectKBest(k=6)
        X_selected = selector.fit_transform(X, y[label])
        
        # classify
        clf = DecisionTreeClassifier()
        clf.fit(X_selected, y[label])
        X_test_selected = selector.transform(X_test)
        classif_results[label] = clf.predict(X_test_selected)

# %%
# clean memory
del X
del y
del X_test

# %%
# transform results to expected output
fn_name_labels = lambda label, pred: list(map(lambda x: label if x else '', pred))
cf_list = [fn_name_labels(k,v) for k,v in classif_results.items()]

# concatenate results
fn_join_columns = lambda x:re.sub('\s+', ' ', ' '.join(x)).strip()

# add new column added products in report
report['added_products'] = list(map(fn_join_columns, zip(*cf_list)))

# %%
report.ix[0, 'added_products']
# Out:
# 'ind_dela_fin_ult1 ind_ctpp_fin_ult1 ind_cco_fin_ult1 ind_valo_fin_ult1'

# %%
report.to_csv('round3b.csv', header=True, index=False)
